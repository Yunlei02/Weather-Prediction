# %% [markdown]
# ## Data cleaning

# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/yunlei/Desktop/MGMT 478/Combined dataset_nonsort.csv')

# %%
data.head()
# Out:
#        STATION                                        NAME  LATITUDE  \
# 0  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 1  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 2  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 3  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 4  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
#
#    LONGITUDE  ELEVATION     DATE  AWND  PRCP  SNOW  TAVG  TMAX  TMIN
# 0  -86.94739      181.7  2010-01   8.5  1.01   NaN  23.5  29.5  17.5
# 1  -86.94739      181.7  2010-02   7.6  0.61   NaN    26  32.8  19.1
# 2  -86.94739      181.7  2010-03   7.2  3.22   NaN  44.8  55.1  34.6
# 3  -86.94739      181.7  2010-04   8.1  2.49   NaN  58.1  70.4  45.8
# 4  -86.94739      181.7  2010-05   6.7  5.55   NaN  64.7  75.2  54.2

# %%
from sklearn.impute import SimpleImputer

# %%
# Convert DATE column to datetime format
data['DATE'] = pd.to_datetime(data['DATE'])

# %%
# Extract year and month from DATE as new features
data['YEAR'] = data['DATE'].dt.year
data['MONTH'] = data['DATE'].dt.month

# %%
# Drop the 'SNOW' column
data_cleaned = data.drop(['SNOW'], axis=1)

# %%
# Convert non-numeric to numeric
for column in ['LATITUDE','LONGITUDE','ELEVATION','AWND', 'TAVG', 'TMAX', 'TMIN']:
    data_cleaned[column] = pd.to_numeric(data_cleaned[column], errors='coerce')

# %%
# Imputer missing data as median of the column
imputer = SimpleImputer(strategy='median')
data_cleaned[['AWND', 'TAVG', 'TMAX', 'TMIN']] = imputer.fit_transform(data_cleaned[['AWND', 'TAVG', 'TMAX', 'TMIN']])

# %%
data_cleaned.head()
# Out:
#        STATION                                        NAME  LATITUDE  \
# 0  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 1  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 2  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 3  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 4  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
#
#    LONGITUDE  ELEVATION       DATE  AWND  PRCP  TAVG  TMAX  TMIN  YEAR  MONTH
# 0  -86.94739      181.7 2010-01-01   8.5  1.01  23.5  29.5  17.5  2010      1
# 1  -86.94739      181.7 2010-02-01   7.6  0.61  26.0  32.8  19.1  2010      2
# 2  -86.94739      181.7 2010-03-01   7.2  3.22  44.8  55.1  34.6  2010      3
# 3  -86.94739      181.7 2010-04-01   8.1  2.49  58.1  70.4  45.8  2010      4
# 4  -86.94739      181.7 2010-05-01   6.7  5.55  64.7  75.2  54.2  2010      5

# %%
data_cleaned.isnull().sum()
# Out:
# STATION      0
# NAME         0
# LATITUDE     0
# LONGITUDE    0
# ELEVATION    0
# DATE         0
# AWND         0
# PRCP         8
# TAVG         0
# TMAX         0
# TMIN         0
# YEAR         0
# MONTH        0
# dtype: int64

# %% [markdown]
# ## Using KNN for finding the nearest stations

# %%
from math import radians, cos, sin, asin, sqrt

def haversine(lon1, lat1, lon2, lat2):
    '''
    Define the Haversack formula function to calculate distance by latitude and longitude
    '''

    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # Mean radius of the Earth in kilometers
    return c * r

# %%
import numpy as np
from sklearn.neighbors import NearestNeighbors

stations = data_cleaned[['STATION', 'LATITUDE', 'LONGITUDE']].drop_duplicates()
coordinates = stations[['LATITUDE', 'LONGITUDE']]
neighbors_model = NearestNeighbors(n_neighbors=6)
neighbors_model.fit(coordinates)

def six_nearest_weather_stations(latitude, longitude):
    query_coordinates = np.array([[latitude, longitude]])
    distances, indices = neighbors_model.kneighbors(query_coordinates)
    nearest_stations_info = stations.iloc[indices[0]].copy() 
    nearest_stations_info['DISTANCE(°)'] = distances[0]
    
    # Calculation of actual distance (km)
    nearest_stations_info['DISTANCE(KM)'] = nearest_stations_info.apply(
        lambda row: haversine(longitude, latitude, row['LONGITUDE'], row['LATITUDE']), 
        axis=1
    )

    return nearest_stations_info

# %%
# Simple average
def average_values_for_nearest_stations(latitude, longitude):
    nearest_stations_info = six_nearest_weather_stations(latitude, longitude)
    nearest_station_ids = nearest_stations_info['STATION'].tolist()
    filtered_data = data_cleaned[data_cleaned['STATION'].isin(nearest_station_ids)]
    average_values = filtered_data.groupby(['YEAR', 'MONTH'])[['AWND', 'PRCP', 'TAVG', 'TMAX', 'TMIN']].mean().reset_index()
    return average_values

# %%
average_values_for_nearest_stations(40,-86)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
#      YEAR  MONTH      AWND      PRCP       TAVG       TMAX       TMIN
# 0    2010      1  9.316667  1.213333  24.000000  30.216667  17.783333
# 1    2010      2  8.500000  1.191667  25.700000  32.316667  19.083333
# 2    2010      3  7.866667  2.888333  44.133333  54.483333  33.833333
# 3    2010      4  9.216667  3.263333  57.683333  69.633333  45.750000
# 4    2010      5  8.116667  5.873333  64.466667  74.383333  54.550000
# ..    ...    ...       ...       ...        ...        ...        ...
# 163  2023      8  6.783333  3.235000  72.400000  82.266667  62.516667
# 164  2023      9  6.100000  1.390000  67.950000  79.350000  56.550000
# 165  2023     10  7.983333  3.301667  56.416667  66.266667  46.583333
# 166  2023     11  8.466667  0.793333  43.583333  54.400000  32.766667
# 167  2023     12  8.080000  1.898000  40.400000  46.940000  33.880000
#
# [168 rows x 7 columns]

# %% [markdown]
# ## Using Purdue Airport to predict

# %% [markdown]
# ### Expand the dataset

# %%
purdue_data = data_cleaned[data_cleaned['STATION']=='USW00014835']

# %%
purdue_data
# Out:
#          STATION                                        NAME  LATITUDE  \
# 0    USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 1    USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 2    USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 3    USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 4    USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# ..           ...                                         ...       ...
# 163  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 164  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 165  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 166  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 167  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
#
#      LONGITUDE  ELEVATION       DATE  AWND  PRCP  TAVG  TMAX  TMIN  YEAR  \
# 0    -86.94739      181.7 2010-01-01   8.5  1.01  23.5  29.5  17.5  2010
# 1    -86.94739      181.7 2010-02-01   7.6  0.61  26.0  32.8  19.1  2010
# 2    -86.94739      181.7 2010-03-01   7.2  3.22  44.8  55.1  34.6  2010
# 3    -86.94739      181.7 2010-04-01   8.1  2.49  58.1  70.4  45.8  2010
# 4    -86.94739      181.7 2010-05-01   6.7  5.55  64.7  75.2  54.2  2010
# ..         ...        ...        ...   ...   ...   ...   ...   ...   ...
# 163  -86.94739      181.7 2023-08-01   5.1  3.54  71.9  81.8  61.9  2023
# 164  -86.94739      181.7 2023-09-01   4.9  0.59  67.5  79.8  55.1  2023
# 165  -86.94739      181.7 2023-10-01   6.3  3.21  55.7  66.3  45.2  2023
# 166  -86.94739      181.7 2023-11-01   6.5  0.48  42.6  53.8  31.5  2023
# 167  -86.94739      181.7 2023-12-01   6.0  2.48  39.5  46.3  32.8  2023
#
#      MONTH
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 163      8
# 164      9
# 165     10
# 166     11
# 167     12
#
# [168 rows x 13 columns]

# %%
purdue_data['DATE'].unique() # each year recorded
# Out:
# <DatetimeArray>
# ['2010-01-01 00:00:00', '2010-02-01 00:00:00', '2010-03-01 00:00:00',
#  '2010-04-01 00:00:00', '2010-05-01 00:00:00', '2010-06-01 00:00:00',
#  '2010-07-01 00:00:00', '2010-08-01 00:00:00', '2010-09-01 00:00:00',
#  '2010-10-01 00:00:00',
#  ...
#  '2023-03-01 00:00:00', '2023-04-01 00:00:00', '2023-05-01 00:00:00',
#  '2023-06-01 00:00:00', '2023-07-01 00:00:00', '2023-08-01 00:00:00',
#  '2023-09-01 00:00:00', '2023-10-01 00:00:00', '2023-11-01 00:00:00',
#  '2023-12-01 00:00:00']
# Length: 168, dtype: datetime64[ns]

# %%
for var in ['AWND', 'PRCP', 'TAVG', 'TMAX', 'TMIN']:
    for year in range(1, 14):
        year_lag = year*12
        purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# Out:
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/3861078926.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purdue_data[f'{var}_lag_{year}_year'] = purdue_data[var].shift(year_lag)

# %%
purdue_data.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'AWND',
#        'PRCP', 'TAVG', 'TMAX', 'TMIN', 'YEAR', 'MONTH', 'AWND_lag_1_year',
#        'AWND_lag_2_year', 'AWND_lag_3_year', 'AWND_lag_4_year',
#        'AWND_lag_5_year', 'AWND_lag_6_year', 'AWND_lag_7_year',
#        'AWND_lag_8_year', 'AWND_lag_9_year', 'AWND_lag_10_year',
#        'AWND_lag_11_year', 'AWND_lag_12_year', 'AWND_lag_13_year',
#        'PRCP_lag_1_year', 'PRCP_lag_2_year', 'PRCP_lag_3_year',
#        'PRCP_lag_4_year', 'PRCP_lag_5_year', 'PRCP_lag_6_year',
#        'PRCP_lag_7_year', 'PRCP_lag_8_year', 'PRCP_lag_9_year',
#        'PRCP_lag_10_year', 'PRCP_lag_11_year', 'PRCP_lag_12_year',
#        'PRCP_lag_13_year', 'TAVG_lag_1_year', 'TAVG_lag_2_year',
#        'TAVG_lag_3_year', 'TAVG_lag_4_year', 'TAVG_lag_5_year',
#        'TAVG_lag_6_year', 'TAVG_lag_7_year', 'TAVG_lag_8_year',
#        'TAVG_lag_9_year', 'TAVG_lag_10_year', 'TAVG_lag_11_year',
#        'TAVG_lag_12_year', 'TAVG_lag_13_year', 'TMAX_lag_1_year',
#        'TMAX_lag_2_year', 'TMAX_lag_3_year', 'TMAX_lag_4_year',
#        'TMAX_lag_5_year', 'TMAX_lag_6_year', 'TMAX_lag_7_year',
#        'TMAX_lag_8_year', 'TMAX_lag_9_year', 'TMAX_lag_10_year',
#        'TMAX_lag_11_year', 'TMAX_lag_12_year', 'TMAX_lag_13_year',
#        'TMIN_lag_1_year', 'TMIN_lag_2_year', 'TMIN_lag_3_year',
#        'TMIN_lag_4_year', 'TMIN_lag_5_year', 'TMIN_lag_6_year',
#        'TMIN_lag_7_year', 'TMIN_lag_8_year', 'TMIN_lag_9_year',
#        'TMIN_lag_10_year', 'TMIN_lag_11_year', 'TMIN_lag_12_year',
#        'TMIN_lag_13_year'],
#       dtype='object')

# %%
six_nearest_weather_stations(40.41236,-86.94739)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
#          STATION  LATITUDE  LONGITUDE  DISTANCE(°)  DISTANCE(KM)
# 0    USW00014835  40.41236  -86.94739     0.000000      0.000000
# 671  USW00093819  39.72515  -86.28160     0.956835     95.125159
# 336  USC00120784  39.17399  -86.52076     1.309799    142.442545
# 839  USW00053866  39.58545  -85.79982     1.414460    134.198553
# 168  USW00014848  41.70722  -86.31628     1.440473    153.395988
# 503  USW00014827  40.97248  -85.20636     1.828912    159.449673

# %%
def average_values_for_nearest_stations_exclude(latitude, longitude, station_to_exclude):
    nearest_stations_info = six_nearest_weather_stations(latitude, longitude)
    nearest_station_ids = nearest_stations_info['STATION'].tolist()
    
    # Remove the specific station ID from the list
    if station_to_exclude in nearest_station_ids:
        nearest_station_ids.remove(station_to_exclude)
    
    filtered_data = data_cleaned[data_cleaned['STATION'].isin(nearest_station_ids)]
    average_values = filtered_data.groupby(['YEAR', 'MONTH'])[['AWND', 'PRCP', 'TAVG', 'TMAX', 'TMIN']].mean().reset_index()
    average_values.rename(columns={
        'AWND': 'AWND_avg',
        'PRCP': 'PRCP_avg',
        'TAVG': 'TAVG_avg',
        'TMAX': 'TMAX_avg',
        'TMIN': 'TMIN_avg'
    }, inplace=True)
    return average_values

# %%
average_values_for_nearest_stations_exclude(40.41236,-86.94739,'USW00014835')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
#      YEAR  MONTH  AWND_avg  PRCP_avg  TAVG_avg  TMAX_avg  TMIN_avg
# 0    2010      1      9.48    1.2540    24.100     30.36     17.84
# 1    2010      2      8.68    1.3080    25.640     32.22     19.08
# 2    2010      3      8.00    2.8220    44.000     54.36     33.68
# 3    2010      4      9.44    3.4180    57.600     69.48     45.74
# 4    2010      5      8.40    5.9380    64.420     74.22     54.62
# ..    ...    ...       ...       ...       ...       ...       ...
# 163  2023      8      7.12    3.1740    72.500     82.36     62.64
# 164  2023      9      6.34    1.5500    68.040     79.26     56.84
# 165  2023     10      8.32    3.3200    56.560     66.26     46.86
# 166  2023     11      8.86    0.8560    43.780     54.52     33.02
# 167  2023     12      8.60    1.7525    40.625     47.10     34.15
#
# [168 rows x 7 columns]

# %%
neighbor_data = average_values_for_nearest_stations_exclude(40.41236,-86.94739,'USW00014835')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(

# %%
merged_data = pd.merge(purdue_data, neighbor_data, on=['YEAR', 'MONTH'], how='inner')

# %%
merged_data
# Out:
#          STATION                                        NAME  LATITUDE  \
# 0    USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 1    USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 2    USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 3    USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 4    USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# ..           ...                                         ...       ...
# 163  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 164  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 165  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 166  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 167  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
#
#      LONGITUDE  ELEVATION       DATE  AWND  PRCP  TAVG  TMAX  ...  \
# 0    -86.94739      181.7 2010-01-01   8.5  1.01  23.5  29.5  ...
# 1    -86.94739      181.7 2010-02-01   7.6  0.61  26.0  32.8  ...
# 2    -86.94739      181.7 2010-03-01   7.2  3.22  44.8  55.1  ...
# 3    -86.94739      181.7 2010-04-01   8.1  2.49  58.1  70.4  ...
# 4    -86.94739      181.7 2010-05-01   6.7  5.55  64.7  75.2  ...
# ..         ...        ...        ...   ...   ...   ...   ...  ...
# 163  -86.94739      181.7 2023-08-01   5.1  3.54  71.9  81.8  ...
# 164  -86.94739      181.7 2023-09-01   4.9  0.59  67.5  79.8  ...
# 165  -86.94739      181.7 2023-10-01   6.3  3.21  55.7  66.3  ...
# 166  -86.94739      181.7 2023-11-01   6.5  0.48  42.6  53.8  ...
# 167  -86.94739      181.7 2023-12-01   6.0  2.48  39.5  46.3  ...
#
#      TMIN_lag_9_year  TMIN_lag_10_year  TMIN_lag_11_year  TMIN_lag_12_year  \
# 0                NaN               NaN               NaN               NaN
# 1                NaN               NaN               NaN               NaN
# 2                NaN               NaN               NaN               NaN
# 3                NaN               NaN               NaN               NaN
# 4                NaN               NaN               NaN               NaN
# ..               ...               ...               ...               ...
# 163             62.4              60.4              58.9              63.1
# 164             51.2              54.8              51.8              55.1
# 165             42.8              43.1              41.4              42.5
# 166             26.6              28.6              29.3              39.6
# 167             26.6              19.7              30.5              29.7
#
#      TMIN_lag_13_year  AWND_avg  PRCP_avg  TAVG_avg  TMAX_avg  TMIN_avg
# 0                 NaN      9.48    1.2540    24.100     30.36     17.84
# 1                 NaN      8.68    1.3080    25.640     32.22     19.08
# 2                 NaN      8.00    2.8220    44.000     54.36     33.68
# 3                 NaN      9.44    3.4180    57.600     69.48     45.74
# 4                 NaN      8.40    5.9380    64.420     74.22     54.62
# ..                ...       ...       ...       ...       ...       ...
# 163              66.0      7.12    3.1740    72.500     82.36     62.64
# 164              55.0      6.34    1.5500    68.040     79.26     56.84
# 165              42.4      8.32    3.3200    56.560     66.26     46.86
# 166              32.0      8.86    0.8560    43.780     54.52     33.02
# 167              17.2      8.60    1.7525    40.625     47.10     34.15
#
# [168 rows x 83 columns]

# %%
for var in ['AWND_avg', 'PRCP_avg', 'TAVG_avg', 'TMAX_avg', 'TMIN_avg']:
    for year in range(1, 14):
        year_lag = year*12
        merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# Out:
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)
# /var/folders/cr/ls79phkx4vb_rmnkc6h2ddqh0000gn/T/ipykernel_14496/742950508.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   merged_data[f'{var}_lag_{year}_year'] = merged_data[var].shift(year_lag)

# %%
merged_data
# Out:
#          STATION                                        NAME  LATITUDE  \
# 0    USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 1    USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 2    USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 3    USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 4    USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# ..           ...                                         ...       ...
# 163  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 164  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 165  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 166  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 167  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
#
#      LONGITUDE  ELEVATION       DATE  AWND  PRCP  TAVG  TMAX  ...  \
# 0    -86.94739      181.7 2010-01-01   8.5  1.01  23.5  29.5  ...
# 1    -86.94739      181.7 2010-02-01   7.6  0.61  26.0  32.8  ...
# 2    -86.94739      181.7 2010-03-01   7.2  3.22  44.8  55.1  ...
# 3    -86.94739      181.7 2010-04-01   8.1  2.49  58.1  70.4  ...
# 4    -86.94739      181.7 2010-05-01   6.7  5.55  64.7  75.2  ...
# ..         ...        ...        ...   ...   ...   ...   ...  ...
# 163  -86.94739      181.7 2023-08-01   5.1  3.54  71.9  81.8  ...
# 164  -86.94739      181.7 2023-09-01   4.9  0.59  67.5  79.8  ...
# 165  -86.94739      181.7 2023-10-01   6.3  3.21  55.7  66.3  ...
# 166  -86.94739      181.7 2023-11-01   6.5  0.48  42.6  53.8  ...
# 167  -86.94739      181.7 2023-12-01   6.0  2.48  39.5  46.3  ...
#
#      TMIN_avg_lag_4_year  TMIN_avg_lag_5_year  TMIN_avg_lag_6_year  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ..                   ...                  ...                  ...
# 163                59.32                65.32                59.68
# 164                57.66                60.38                56.16
# 165                45.36                44.94                48.16
# 166                28.66                30.50                33.64
# 167                27.78                28.78                20.84
#
#      TMIN_avg_lag_7_year  TMIN_avg_lag_8_year  TMIN_avg_lag_9_year  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ..                   ...                  ...                  ...
# 163                67.42                61.32                63.48
# 164                59.74                57.98                53.20
# 165                49.32                45.26                44.26
# 166                37.38                37.18                27.84
# 167                22.46                35.42                28.38
#
#      TMIN_avg_lag_10_year  TMIN_avg_lag_11_year  TMIN_avg_lag_12_year  \
# 0                     NaN                   NaN                   NaN
# 1                     NaN                   NaN                   NaN
# 2                     NaN                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4                     NaN                   NaN                   NaN
# ..                    ...                   ...                   ...
# 163                 61.80                 60.62                 62.72
# 164                 55.70                 54.10                 54.76
# 165                 44.10                 42.80                 43.04
# 166                 31.02                 30.34                 38.94
# 167                 21.80                 31.36                 30.18
#
#      TMIN_avg_lag_13_year
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ..                    ...
# 163                 65.44
# 164                 55.32
# 165                 43.18
# 166                 31.78
# 167                 18.58
#
# [168 rows x 148 columns]

# %%
merged_data_final = merged_data.drop(columns=['AWND', 'TAVG', 'TMAX', 'TMIN', 'AWND_avg', 'PRCP_avg', 'TAVG_avg', 'TMAX_avg', 'TMIN_avg'])

# %% [markdown]
# ### Lasso: top 5 feature selection

# %%
years = merged_data_final['YEAR'].unique()

# %%
years
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
#        2021, 2022, 2023], dtype=int32)

# %%
features_df = merged_data_final.drop(columns=['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'PRCP'])

# %%
features_df
# Out:
#      YEAR  MONTH  AWND_lag_1_year  AWND_lag_2_year  AWND_lag_3_year  \
# 0    2010      1              NaN              NaN              NaN
# 1    2010      2              NaN              NaN              NaN
# 2    2010      3              NaN              NaN              NaN
# 3    2010      4              NaN              NaN              NaN
# 4    2010      5              NaN              NaN              NaN
# ..    ...    ...              ...              ...              ...
# 163  2023      8              4.9              4.9              4.7
# 164  2023      9              5.1              6.0              5.8
# 165  2023     10              6.9              5.8              7.2
# 166  2023     11              7.6              6.7              7.8
# 167  2023     12              8.7              7.6              7.4
#
#      AWND_lag_4_year  AWND_lag_5_year  AWND_lag_6_year  AWND_lag_7_year  \
# 0                NaN              NaN              NaN              NaN
# 1                NaN              NaN              NaN              NaN
# 2                NaN              NaN              NaN              NaN
# 3                NaN              NaN              NaN              NaN
# 4                NaN              NaN              NaN              NaN
# ..               ...              ...              ...              ...
# 163              5.1              4.9              4.5              4.7
# 164              4.9              5.8              4.9              5.4
# 165              6.9              6.9              6.7              6.5
# 166              6.9              7.8              7.4              6.3
# 167              7.2              7.2              7.6              8.5
#
#      AWND_lag_8_year  ...  TMIN_avg_lag_4_year  TMIN_avg_lag_5_year  \
# 0                NaN  ...                  NaN                  NaN
# 1                NaN  ...                  NaN                  NaN
# 2                NaN  ...                  NaN                  NaN
# 3                NaN  ...                  NaN                  NaN
# 4                NaN  ...                  NaN                  NaN
# ..               ...  ...                  ...                  ...
# 163              4.9  ...                59.32                65.32
# 164              5.4  ...                57.66                60.38
# 165              8.3  ...                45.36                44.94
# 166              8.1  ...                28.66                30.50
# 167              8.9  ...                27.78                28.78
#
#      TMIN_avg_lag_6_year  TMIN_avg_lag_7_year  TMIN_avg_lag_8_year  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ..                   ...                  ...                  ...
# 163                59.68                67.42                61.32
# 164                56.16                59.74                57.98
# 165                48.16                49.32                45.26
# 166                33.64                37.38                37.18
# 167                20.84                22.46                35.42
#
#      TMIN_avg_lag_9_year  TMIN_avg_lag_10_year  TMIN_avg_lag_11_year  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# ..                   ...                   ...                   ...
# 163                63.48                 61.80                 60.62
# 164                53.20                 55.70                 54.10
# 165                44.26                 44.10                 42.80
# 166                27.84                 31.02                 30.34
# 167                28.38                 21.80                 31.36
#
#      TMIN_avg_lag_12_year  TMIN_avg_lag_13_year
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
# ..                    ...                   ...
# 163                 62.72                 65.44
# 164                 54.76                 55.32
# 165                 43.04                 43.18
# 166                 38.94                 31.78
# 167                 30.18                 18.58
#
# [168 rows x 132 columns]

# %%
train_df = merged_data_final[merged_data_final['YEAR'] == 2011]
test_df = merged_data_final[merged_data_final['YEAR'] == 2011 + 1]

# %%
pd.set_option('display.max_rows', None)

# %%
train_df.isnull().sum()
# Out:
# STATION                  0
# NAME                     0
# LATITUDE                 0
# LONGITUDE                0
# ELEVATION                0
# DATE                     0
# PRCP                     0
# YEAR                     0
# MONTH                    0
# AWND_lag_1_year          0
# AWND_lag_2_year         12
# AWND_lag_3_year         12
# AWND_lag_4_year         12
# AWND_lag_5_year         12
# AWND_lag_6_year         12
# AWND_lag_7_year         12
# AWND_lag_8_year         12
# AWND_lag_9_year         12
# AWND_lag_10_year        12
# AWND_lag_11_year        12
# AWND_lag_12_year        12
# AWND_lag_13_year        12
# PRCP_lag_1_year          0
# PRCP_lag_2_year         12
# PRCP_lag_3_year         12
# PRCP_lag_4_year         12
# PRCP_lag_5_year         12
# PRCP_lag_6_year         12
# PRCP_lag_7_year         12
# PRCP_lag_8_year         12
# PRCP_lag_9_year         12
# PRCP_lag_10_year        12
# PRCP_lag_11_year        12
# PRCP_lag_12_year        12
# PRCP_lag_13_year        12
# TAVG_lag_1_year          0
# TAVG_lag_2_year         12
# TAVG_lag_3_year         12
# TAVG_lag_4_year         12
# TAVG_lag_5_year         12
# TAVG_lag_6_year         12
# TAVG_lag_7_year         12
# TAVG_lag_8_year         12
# TAVG_lag_9_year         12
# TAVG_lag_10_year        12
# TAVG_lag_11_year        12
# TAVG_lag_12_year        12
# TAVG_lag_13_year        12
# TMAX_lag_1_year          0
# TMAX_lag_2_year         12
# TMAX_lag_3_year         12
# TMAX_lag_4_year         12
# TMAX_lag_5_year         12
# TMAX_lag_6_year         12
# TMAX_lag_7_year         12
# TMAX_lag_8_year         12
# TMAX_lag_9_year         12
# TMAX_lag_10_year        12
# TMAX_lag_11_year        12
# TMAX_lag_12_year        12
# TMAX_lag_13_year        12
# TMIN_lag_1_year          0
# TMIN_lag_2_year         12
# TMIN_lag_3_year         12
# TMIN_lag_4_year         12
# TMIN_lag_5_year         12
# TMIN_lag_6_year         12
# TMIN_lag_7_year         12
# TMIN_lag_8_year         12
# TMIN_lag_9_year         12
# TMIN_lag_10_year        12
# TMIN_lag_11_year        12
# TMIN_lag_12_year        12
# TMIN_lag_13_year        12
# AWND_avg_lag_1_year      0
# AWND_avg_lag_2_year     12
# AWND_avg_lag_3_year     12
# AWND_avg_lag_4_year     12
# AWND_avg_lag_5_year     12
# AWND_avg_lag_6_year     12
# AWND_avg_lag_7_year     12
# AWND_avg_lag_8_year     12
# AWND_avg_lag_9_year     12
# AWND_avg_lag_10_year    12
# AWND_avg_lag_11_year    12
# AWND_avg_lag_12_year    12
# AWND_avg_lag_13_year    12
# PRCP_avg_lag_1_year      0
# PRCP_avg_lag_2_year     12
# PRCP_avg_lag_3_year     12
# PRCP_avg_lag_4_year     12
# PRCP_avg_lag_5_year     12
# PRCP_avg_lag_6_year     12
# PRCP_avg_lag_7_year     12
# PRCP_avg_lag_8_year     12
# PRCP_avg_lag_9_year     12
# PRCP_avg_lag_10_year    12
# PRCP_avg_lag_11_year    12
# PRCP_avg_lag_12_year    12
# PRCP_avg_lag_13_year    12
# TAVG_avg_lag_1_year      0
# TAVG_avg_lag_2_year     12
# TAVG_avg_lag_3_year     12
# TAVG_avg_lag_4_year     12
# TAVG_avg_lag_5_year     12
# TAVG_avg_lag_6_year     12
# TAVG_avg_lag_7_year     12
# TAVG_avg_lag_8_year     12
# TAVG_avg_lag_9_year     12
# TAVG_avg_lag_10_year    12
# TAVG_avg_lag_11_year    12
# TAVG_avg_lag_12_year    12
# TAVG_avg_lag_13_year    12
# TMAX_avg_lag_1_year      0
# TMAX_avg_lag_2_year     12
# TMAX_avg_lag_3_year     12
# TMAX_avg_lag_4_year     12
# TMAX_avg_lag_5_year     12
# TMAX_avg_lag_6_year     12
# TMAX_avg_lag_7_year     12
# TMAX_avg_lag_8_year     12
# TMAX_avg_lag_9_year     12
# TMAX_avg_lag_10_year    12
# TMAX_avg_lag_11_year    12
# TMAX_avg_lag_12_year    12
# TMAX_avg_lag_13_year    12
# TMIN_avg_lag_1_year      0
# TMIN_avg_lag_2_year     12
# TMIN_avg_lag_3_year     12
# TMIN_avg_lag_4_year     12
# TMIN_avg_lag_5_year     12
# TMIN_avg_lag_6_year     12
# TMIN_avg_lag_7_year     12
# TMIN_avg_lag_8_year     12
# TMIN_avg_lag_9_year     12
# TMIN_avg_lag_10_year    12
# TMIN_avg_lag_11_year    12
# TMIN_avg_lag_12_year    12
# TMIN_avg_lag_13_year    12
# dtype: int64

# %%
train_df = train_df.dropna(axis=1, how='all')

# %%
train_df
# Out:
#         STATION                                        NAME  LATITUDE  \
# 12  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 13  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 14  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 15  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 16  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 17  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 18  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 19  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 20  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 21  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 22  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
# 23  USW00014835  LAFAYETTE PURDUE UNIVERSITY AIRPORT, IN US  40.41236
#
#     LONGITUDE  ELEVATION       DATE  PRCP  YEAR  MONTH  AWND_lag_1_year  \
# 12  -86.94739      181.7 2011-01-01  0.73  2011      1              8.5
# 13  -86.94739      181.7 2011-02-01  2.66  2011      2              7.6
# 14  -86.94739      181.7 2011-03-01  2.15  2011      3              7.2
# 15  -86.94739      181.7 2011-04-01  7.89  2011      4              8.1
# 16  -86.94739      181.7 2011-05-01  1.32  2011      5              6.7
# 17  -86.94739      181.7 2011-06-01  6.51  2011      6              5.6
# 18  -86.94739      181.7 2011-07-01  3.41  2011      7              4.3
# 19  -86.94739      181.7 2011-08-01  4.97  2011      8              3.8
# 20  -86.94739      181.7 2011-09-01  3.83  2011      9              6.0
# 21  -86.94739      181.7 2011-10-01  2.49  2011     10              6.3
# 22  -86.94739      181.7 2011-11-01  5.62  2011     11              7.4
# 23  -86.94739      181.7 2011-12-01  3.31  2011     12              7.4
#
#     PRCP_lag_1_year  TAVG_lag_1_year  TMAX_lag_1_year  TMIN_lag_1_year  \
# 12             1.01             23.5             29.5             17.5
# 13             0.61             26.0             32.8             19.1
# 14             3.22             44.8             55.1             34.6
# 15             2.49             58.1             70.4             45.8
# 16             5.55             64.7             75.2             54.2
# 17             9.61             74.6             84.3             64.8
# 18             4.04             76.8             86.8             66.9
# 19             2.23             76.8             87.7             66.0
# 20             1.81             67.5             80.0             55.0
# 21             0.97             56.4             70.4             42.4
# 22             3.50             43.6             55.2             32.0
# 23             1.26             24.1             31.0             17.2
#
#     AWND_avg_lag_1_year  PRCP_avg_lag_1_year  TAVG_avg_lag_1_year  \
# 12                 9.48                1.254                24.10
# 13                 8.68                1.308                25.64
# 14                 8.00                2.822                44.00
# 15                 9.44                3.418                57.60
# 16                 8.40                5.938                64.42
# 17                 7.64                8.366                74.12
# 18                 6.80                2.906                77.18
# 19                 5.90                1.334                76.34
# 20                 8.18                1.024                67.56
# 21                 8.36                1.248                56.18
# 22                 8.70                4.820                42.98
# 23                 8.98                1.530                24.96
#
#     TMAX_avg_lag_1_year  TMIN_avg_lag_1_year
# 12                30.36                17.84
# 13                32.22                19.08
# 14                54.36                33.68
# 15                69.48                45.74
# 16                74.22                54.62
# 17                83.52                64.74
# 18                87.10                67.30
# 19                87.26                65.44
# 20                79.80                55.32
# 21                69.20                43.18
# 22                54.20                31.78
# 23                31.34                18.58

# %%
features_df.columns
# Out:
# Index(['YEAR', 'MONTH', 'AWND_lag_1_year', 'AWND_lag_2_year',
#        'AWND_lag_3_year', 'AWND_lag_4_year', 'AWND_lag_5_year',
#        'AWND_lag_6_year', 'AWND_lag_7_year', 'AWND_lag_8_year',
#        ...
#        'TMIN_avg_lag_4_year', 'TMIN_avg_lag_5_year', 'TMIN_avg_lag_6_year',
#        'TMIN_avg_lag_7_year', 'TMIN_avg_lag_8_year', 'TMIN_avg_lag_9_year',
#        'TMIN_avg_lag_10_year', 'TMIN_avg_lag_11_year', 'TMIN_avg_lag_12_year',
#        'TMIN_avg_lag_13_year'],
#       dtype='object', length=132)

# %%
from sklearn.linear_model import LassoCV
from sklearn.metrics import mean_squared_error
import numpy as np

mse_values = {}
top_features_per_year = {} 

for year in years[1:-1]:  # Exclude the last year as it has no next year for testing
    # Splitting the dataset into current year (for training) and next year (for testing)
    train_df = merged_data_final[merged_data_final['YEAR'] == year]
    test_df = merged_data_final[merged_data_final['YEAR'] == year + 1]
    
    # Dropping rows with missing values in both train and test datasets
    train_df = train_df.dropna(axis=1, how='all')
    test_df = test_df.dropna(axis=1, how='all')
    
    features_df = train_df.drop(columns=['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'PRCP', 'YEAR'])
    
    # Extracting features and target for training and testing
    X_train = train_df[features_df.columns]
    y_train = train_df['PRCP']
    X_test = test_df[features_df.columns]
    y_test = test_df['PRCP']
    
    # Check if there's enough data to proceed
    if X_train.empty or X_test.empty:
        continue
    
    # Using LassoCV for feature selection and to fit the model
    lasso = LassoCV(cv=5).fit(X_train, y_train)
    
    # Predicting on the next year's data
    y_pred = lasso.predict(X_test)
    
    # Calculating MSE for the prediction
    mse = mean_squared_error(y_test, y_pred)
    
    # Storing the MSE value
    mse_values[year] = mse
    
    # Get the feature coefficients and their corresponding feature names
    feature_importance = np.abs(lasso.coef_)
    feature_names = X_train.columns
    features_coef = zip(feature_names, feature_importance)
    
    # Sort the features by the absolute value of their coefficient
    top_features = sorted(features_coef, key=lambda x: x[1], reverse=True)[:5]
    
    # Store the top features for the year
    top_features_per_year[year] = top_features

# Displaying the results
(top_features_per_year, mse_values)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.098e-03, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.522e-01, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.325e-01, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.098e-01, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.387e-01, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.543e-01, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.622e-01, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.361e-01, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.014e-01, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.529e-01, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.879e-01, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.029e-01, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.062e-01, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.469e-01, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.892e-01, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.204e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.414e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.545e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.621e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.657e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.666e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.654e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.630e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.595e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.553e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.530e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.684e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.792e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.856e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.884e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.883e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.859e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.817e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.773e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.871e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.972e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.118e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.259e+00, tolerance: 3.407e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.798e-02, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.992e-02, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.692e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.431e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.067e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.746e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.460e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.057e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.534e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.898e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.158e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.716e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.212e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.788e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.425e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.110e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.832e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.583e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.597e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.780e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.894e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.947e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.950e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.908e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.839e-01, tolerance: 1.743e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.454e-02, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.924e-01, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.722e-01, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.238e-03, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.505e-02, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.487e-01, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.229e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.949e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.628e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.237e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.765e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.213e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.585e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.887e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.962e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.957e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.953e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.943e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.929e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.909e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.883e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.852e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.874e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.948e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.009e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.041e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.047e+00, tolerance: 4.872e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.393e-02, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.651e-01, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.101e-01, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.323e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.862e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.400e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.936e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.543e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.387e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.165e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.827e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.411e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.914e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.339e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.695e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.002e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.248e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.432e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.563e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.758e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.943e+00, tolerance: 4.871e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.632e-03, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.574e-01, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.666e-01, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.554e-01, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.283e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.723e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.146e-01, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.011e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.671e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.315e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.857e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.291e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.671e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.999e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.341e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.643e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.898e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.110e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.286e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.429e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.551e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.648e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.717e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.764e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.793e+00, tolerance: 4.649e-03
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.070e-03, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.301e-03, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.319e-03, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.243e-03, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.129e-03, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.002e-03, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.874e-03, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.751e-03, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.634e-03, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.524e-03, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.421e-03, tolerance: 1.375e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.533e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.636e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.653e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.095e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.379e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.343e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.515e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.598e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.706e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.582e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.133e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.048e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.575e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.340e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.117e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.909e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.714e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.532e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.362e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.204e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.056e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.918e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.789e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.669e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.557e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.453e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.355e-03, tolerance: 1.266e-03
#   model = cd_fast.enet_coordinate_descent(
# ({2011: [('MONTH', 0.0),
#    ('AWND_lag_1_year', 0.0),
#    ('PRCP_lag_1_year', 0.0),
#    ('TAVG_lag_1_year', 0.0),
#    ('TMAX_lag_1_year', 0.0)],
#   2012: [('TMAX_lag_2_year', 0.013655749030638698),
#    ('MONTH', 0.0),
#    ('AWND_lag_1_year', 0.0),
#    ('AWND_lag_2_year', 0.0),
#    ('PRCP_lag_1_year', 0.0)],
#   2013: [('MONTH', 0.0),
#    ('AWND_lag_1_year', 0.0),
#    ('AWND_lag_2_year', 0.0),
#    ('AWND_lag_3_year', 0.0),
#    ('PRCP_lag_1_year', 0.0)],
#   2014: [('TMAX_lag_1_year', 0.04181335401256917),
#    ('TMAX_lag_4_year', 0.00942895929187475),
#    ('MONTH', 0.0),
#    ('AWND_lag_1_year', 0.0),
#    ('AWND_lag_2_year', 0.0)],
#   2015: [('PRCP_avg_lag_2_year', 0.7575897830589432),
#    ('PRCP_lag_5_year', 0.3943092826465581),
#    ('PRCP_lag_3_year', 0.30070920813789115),
#    ('TAVG_lag_5_year', 0.18692508037282163),
#    ('TMIN_avg_lag_3_year', 0.16913884236835708)],
#   2016: [('TMAX_lag_4_year', 0.051297560155605534),
#    ('MONTH', 0.0),
#    ('AWND_lag_1_year', 0.0),
#    ('AWND_lag_2_year', 0.0),
#    ('AWND_lag_3_year', 0.0)],
#   2017: [('TMAX_lag_5_year', 0.067056581234361),
#    ('MONTH', 0.0),
#    ('AWND_lag_1_year', 0.0),
#    ('AWND_lag_2_year', 0.0),
#    ('AWND_lag_3_year', 0.0)],
#   2018: [('TMIN_avg_lag_4_year', 0.015107801290851871),
#    ('TMAX_lag_1_year', 0.0032211430242680326),
#    ('MONTH', 0.0),
#    ('AWND_lag_1_year', 0.0),
#    ('AWND_lag_2_year', 0.0)],
#   2019: [('MONTH', 0.0),
#    ('AWND_lag_1_year', 0.0),
#    ('AWND_lag_2_year', 0.0),
#    ('AWND_lag_3_year', 0.0),
#    ('AWND_lag_4_year', 0.0)],
#   2020: [('TMIN_lag_2_year', 0.014355639269666085),
#    ('TMAX_avg_lag_10_year', 0.004575509804125434),
#    ('MONTH', 0.0),
#    ('AWND_lag_1_year', 0.0),
#    ('AWND_lag_2_year', 0.0)],
#   2021: [('MONTH', 0.0),
#    ('AWND_lag_1_year', 0.0),
#    ('AWND_lag_2_year', 0.0),
#    ('AWND_lag_3_year', 0.0),
#    ('AWND_lag_4_year', 0.0)],
#   2022: [('MONTH', 0.0),
#    ('AWND_lag_1_year', 0.0),
#    ('AWND_lag_2_year', 0.0),
#    ('AWND_lag_3_year', 0.0),
#    ('AWND_lag_4_year', 0.0)]},
#  {2011: 3.669613194444444,
#   2012: 3.665475216365721,
#   2013: 1.8688083333333336,
#   2014: 5.02098712135482,
#   2015: 3.3331484139532885,
#   2016: 4.050075890129659,
#   2017: 1.9109668800726987,
#   2018: 1.7112143182964112,
#   2019: 0.6943805555555552,
#   2020: 5.5605562342510595,
#   2021: 3.796358333333334,
#   2022: 3.156764583333334})
